# %%
# %pip install yfinance pandas matplotlib seaborn
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
def fetch_stock_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    stock_data = stock.history(start=start_date, end=end_date)
    return stock_data
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
ticker = 'ADX'
start_date = '2013-01-01'
end_date = '2024-01-01'
stock_data = fetch_stock_data(ticker, start_date, end_date)
print(stock_data.head())
plot_stock_data(stock_data, ticker)
plot_moving_average(stock_data, ticker, 50)
# Out:
# Failed to get ticker 'ADX' reason: object of type 'NoneType' has no len()
# $ADX: possibly delisted; No timezone found
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# %pip install yfinance pandas matplotlib seaborn
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
def fetch_stock_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    stock_data = stock.history(start=start_date, end=end_date)
    if stock_data.empty:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
    return stock_data

def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
ticker = 'ADX' 
start_date = '2013-01-01'
end_date = '2024-01-01'
    stock_data = fetch_stock_data(ticker, start_date, end_date)
    print:(stock_data.head())
    plot_stock_data(stock_data, ticker)
    plot_moving_average(stock_data, ticker, 50)
except ValueError as e:
    print(e)
# Out:
#   Cell In[5], line 40
#     stock_data = fetch_stock_data(ticker, start_date, end_date)
#     ^
# IndentationError: unexpected indent

# %%
# Install the necessary libraries
# %pip install yfinance pandas matplotlib seaborn

# Import the libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    stock_data = stock.history(start=start_date, end=end_date)
    if stock_data.empty:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
    return stock_data

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'AAPL'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Display the first few rows of the data
    print(stock_data.head())

    # Plot the stock data
    plot_stock_data(stock_data, ticker)

    # Plot the stock data with a 50-day moving average
    plot_moving_average(stock_data, ticker, 50)
except ValueError as e:
    print(e)
# Out:
# Failed to get ticker 'AAPL' reason: object of type 'NoneType' has no len()
# $AAPL: possibly delisted; No timezone found
# No data found for ticker AAPL. It may be delisted or the symbol is incorrect.

# %%
# Install the necessary libraries
# %pip install yfinance pandas matplotlib seaborn

# Import the libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'ADX'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Display the first few rows of the data
    print(stock_data.head())

    # Plot the stock data
    plot_stock_data(stock_data, ticker)

    # Plot the stock data with a 50-day moving average
    plot_moving_average(stock_data, ticker, 50)
except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ERROR:yfinance:Failed to get ticker 'ADX' reason: object of type 'NoneType' has no len()
# ERROR:yfinance:$ADX: possibly delisted; No timezone found
# ERROR:root:Failed to get ticker 'ADX' reason: No data found for ticker ADX. It may be delisted or the symbol is incorrect.
# No data found for ticker ADX. It may be delisted or the symbol is incorrect.

# %%
# Install the necessary libraries
# %pip install yfinance pandas matplotlib seaborn

# Import the libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'AAPL'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Display the first few rows of the data
    print(stock_data.head())

    # Plot the stock data
    plot_stock_data(stock_data, ticker)

    # Plot the stock data with a 50-day moving average
    plot_moving_average(stock_data, ticker, 50)
except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ERROR:yfinance:Failed to get ticker 'AAPL' reason: object of type 'NoneType' has no len()
# ERROR:yfinance:$AAPL: possibly delisted; No timezone found
# ERROR:root:Failed to get ticker 'AAPL' reason: No data found for ticker AAPL. It may be delisted or the symbol is incorrect.
# No data found for ticker AAPL. It may be delisted or the symbol is incorrect.

# %%
# Install the necessary libraries
# %pip install yfinance pandas matplotlib seaborn

# Import the libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'GME'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Display the first few rows of the data
    print(stock_data.head())

    # Plot the stock data
    plot_stock_data(stock_data, ticker)

    # Plot the stock data with a 50-day moving average
    plot_moving_average(stock_data, ticker, 50)
except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ERROR:yfinance:Failed to get ticker 'GME' reason: object of type 'NoneType' has no len()
# ERROR:yfinance:$GME: possibly delisted; No timezone found
# ERROR:root:Failed to get ticker 'GME' reason: No data found for ticker GME. It may be delisted or the symbol is incorrect.
# No data found for ticker GME. It may be delisted or the symbol is incorrect.

# %%
# Install the necessary libraries
# !pip install yfinance pandas matplotlib seaborn

# Import the libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data is None or stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'GME'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Check if data is available
    if stock_data is not None and not stock_data.empty:
        # Display the first few rows of the data
        print(stock_data.head())

        # Plot the stock data
        plot_stock_data(stock_data, ticker)

        # Plot the stock data with a 50-day moving average
        plot_moving_average(stock_data, ticker, 50)
    else:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")

except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Install the necessary libraries
# ----> 2 get_ipython().system('pip install yfinance pandas matplotlib seaborn')
#       4 # Import the libraries
#       5 import yfinance as yf
#
# File /lib/python3.11/site-packages/IPython/core/interactiveshell.py:2653, in InteractiveShell.system_piped(self, cmd)
#    2648     raise OSError("Background processes not supported.")
#    2650 # we explicitly do NOT return the subprocess status code, because
#    2651 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2652 # Instead, we store the exit_code in user_ns.
# -> 2653 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File /lib/python3.11/site-packages/IPython/utils/_process_emscripten.py:11, in system(cmd)
#      10 def system(cmd):
# ...

# %%
# Install the necessary libraries using pip within the notebook
# !pip install yfinance pandas matplotlib seaborn

# Now you can import the libraries and continue with the rest of the code
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data is None or stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'GME'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Check if data is available
    if stock_data is not None and not stock_data.empty:
        # Display the first few rows of the data
        print(stock_data.head())

        # Plot the stock data
        plot_stock_data(stock_data, ticker)

        # Plot the stock data with a 50-day moving average
        plot_moving_average(stock_data, ticker, 50)
    else:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")

except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Install the necessary libraries using pip within the notebook
# ----> 2 get_ipython().system('pip install yfinance pandas matplotlib seaborn')
#       4 # Now you can import the libraries and continue with the rest of the code
#       5 import yfinance as yf
#
# File /lib/python3.11/site-packages/IPython/core/interactiveshell.py:2653, in InteractiveShell.system_piped(self, cmd)
#    2648     raise OSError("Background processes not supported.")
#    2650 # we explicitly do NOT return the subprocess status code, because
#    2651 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2652 # Instead, we store the exit_code in user_ns.
# -> 2653 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# ...

# %%
# Install the necessary libraries using pip within the notebook
# !pip install yfinance pandas matplotlib seaborn

# Now you can import the libraries and continue with the rest of the code
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data is None or stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'GME'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Check if data is available
    if stock_data is not None and not stock_data.empty:
        # Display the first few rows of the data
        print(stock_data.head())

        # Plot the stock data
        plot_stock_data(stock_data, ticker)

        # Plot the stock data with a 50-day moving average
        plot_moving_average(stock_data, ticker, 50)
    else:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")

except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Install the necessary libraries using pip within the notebook
# ----> 2 get_ipython().system('pip install yfinance pandas matplotlib seaborn')
#       4 # Now you can import the libraries and continue with the rest of the code
#       5 import yfinance as yf
#
# File /lib/python3.11/site-packages/IPython/core/interactiveshell.py:2653, in InteractiveShell.system_piped(self, cmd)
#    2648     raise OSError("Background processes not supported.")
#    2650 # we explicitly do NOT return the subprocess status code, because
#    2651 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2652 # Instead, we store the exit_code in user_ns.
# -> 2653 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# ...

# %%
# Install the necessary libraries using pip within the notebook
# !pip install yfinance pandas matplotlib seaborn

# Now you can import the libraries and continue with the rest of the code
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import logging

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# Function to fetch stock data
def fetch_stock_data(ticker, start_date, end_date):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(start=start_date, end=end_date)
        if stock_data is None or stock_data.empty:
            raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")
        return stock_data
    except Exception as e:
        logger.error(f"Failed to get ticker '{ticker}' reason: {e}")
        raise

# Function to calculate moving average
def calculate_moving_average(data, window):
    return data['Close'].rolling(window=window).mean()

# Function to plot stock data
def plot_stock_data(data, ticker):
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Function to plot moving average
def plot_moving_average(data, ticker, window):
    moving_avg = calculate_moving_average(data, window)
    plt.figure(figsize=(14, 7))
    plt.plot(data['Close'], label='Close Price')
    plt.plot(moving_avg, label=f'{window}-Day Moving Average')
    plt.title(f'{ticker} Stock Price with {window}-Day Moving Average')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# Define the stock ticker, start date, and end date
ticker = 'GME'  # Changed to a known valid ticker
start_date = '2013-01-01'
end_date = '2024-01-01'

try:
    # Fetch the stock data
    stock_data = fetch_stock_data(ticker, start_date, end_date)

    # Check if data is available
    if stock_data is not None and not stock_data.empty:
        # Display the first few rows of the data
        print(stock_data.head())

        # Plot the stock data
        plot_stock_data(stock_data, ticker)

        # Plot the stock data with a 50-day moving average
        plot_moving_average(stock_data, ticker, 50)
    else:
        raise ValueError(f"No data found for ticker {ticker}. It may be delisted or the symbol is incorrect.")

except ValueError as e:
    print(e)
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Install the necessary libraries using pip within the notebook
# ----> 2 get_ipython().system('pip install yfinance pandas matplotlib seaborn')
#       4 # Now you can import the libraries and continue with the rest of the code
#       5 import yfinance as yf
#
# File /lib/python3.11/site-packages/IPython/core/interactiveshell.py:2653, in InteractiveShell.system_piped(self, cmd)
#    2648     raise OSError("Background processes not supported.")
#    2650 # we explicitly do NOT return the subprocess status code, because
#    2651 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2652 # Instead, we store the exit_code in user_ns.
# -> 2653 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# ...
